# %% [markdown]
# # Jupyter_Notebook.ipyng

# %% [markdown]
# Презентация о Jupyter в Jupyter
# * https://github.com/hukenovs/dsp-theory/tree/master
# * [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/Placebo-relay/my-first-binder/HEAD?labpath=G6.ipynb)
# * https://colab.research.google.com/drive/1KRNDUU2lZpnA1BsovOX7Le8TaZAfNRdp?usp=sharing#scrollTo=4lA0w8FpZMf-
# * https://mybinder.org/repo/AllenDowney/ThinkDSP

# %% [markdown]
# ![image.png](attachment:5c43655b-7361-444d-8a01-21d8c2c7e726.png)

# %% [markdown]
# ## 1. Возможности

# %% [markdown]
# ### Блоки кода
#     * Markdown
#     * Code

# %%
print('Можно обойтись без принта')
'Принт'
# Out:
# Можно обойтись без принта
# 'Принт'

# %% [markdown]
# Это блок Markdown, следующий блок Code

# %%
a = 1
a
# Out:
# 1

# %% [markdown]
# #### Test

# %%
#### Test

# %% [markdown]
# ### LaTeX

# %% [markdown]
# Пример LaTeX отдельно в лекции от hukenovs "dsp-theory" via Github

# %% [markdown]
# ### Богатый вывод: виджеты, пакеты визуализаций, датасеты

# %% [markdown]
#  Разбор отдельно в лекции от hukenovs "dsp-theory" via Github

# %% [markdown]
# ### Браузерный подход и элементы интерфейса

# %% [markdown]
# Потестить непосредственно в Jupyter:
# * Ядро kernel
# * Древо файлов
# * Консоль
# * Сохранить как pdf, py, etc.
# * Темы (светлая, темная)
# * Настройки
# * Полезный Help (особенно про Markdown)

# %% [markdown]
# ## 2. Лицензия BSD-3-Clause (разрешено всё)

# %% [markdown]
# ### Ссылка на сайт и репозиторий

# %% [markdown]
# * https://jupyter.org
# * https://github.com/jupyter

# %% [markdown]
# ## 3. Подсветка, автодополнение, сворачивание
# * Базовый линтер
# * Автодополнение Tab
# * Сворачивание блоков
# * (доп LSP в т.ч. под другие языки можно найти в плагинах)

# %% [markdown]
# ## 4. Без PEP8
# * но всегда есть плагины и есть доступ к консоли (autopep, black)

# %% [markdown]
# ## 5. Built-in env

# %% [markdown]
# Jupyter Notebook может работать с виртуальными средами, созданными с помощью Conda, venv или virtualenv, позволяя пользователю использовать изолированные среды для своей работы. Перед запуском Jupyter Notebook необходимо активировать нужную виртуальную среду или заранее отконфигурировать среду в отдельное ядро.

# %% [markdown]
# ## 6. Обработка ошибок %debug

# %%
# a = [1, 2, 3]
# prin(a)
# a[3]

# %% [markdown]
# ## 7. Plugins

# %% [markdown]
# рекомендую: awesome jupyter list https://github.com/markusschanta/awesome-jupyter
# * RISE - presentation
# * autopep/black
# * LSP++ https://github.com/jupyter-lsp/jupyterlab-lsp

# %% [markdown]
# ## 8. Уникальные фичи

# %% [markdown]
# * Binder https://mybinder.org https://mybinder.org/repo/AllenDowney/ThinkDSP
# * GoogleColab https://colab.research.google.com/drive/1KRNDUU2lZpnA1BsovOX7Le8TaZAfNRdp?usp=sharing#scrollTo=4lA0w8FpZMf-
# * JupyterHub (multi-user)

# %% [markdown]
# ## 9. Ресурсы (4GB + >1 core)

# %% [markdown]
# ## 10. Вывод + magic

# %%
# %alias_magic t timeit
# Out:
# Created `%t` as an alias for `%timeit`.
# Created `%%t` as an alias for `%%timeit`.

# %% [markdown]
# https://ipython.readthedocs.io/en/stable/interactive/magics.html

# %%
# %t a = 1
# Out:
# 20.7 ns ± 3.03 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)
