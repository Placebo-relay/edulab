# %% [markdown]
# # Super Power Data (14)

# %%
import pandas as pd

# %%
PATH = 'super_hero_powers.csv'
original_data = pd.read_csv(PATH)

original_data.head()
# Out:
#     hero_names  Agility  Accelerated Healing  Lantern Power Ring  \
# 0      3-D Man     True                False               False
# 1       A-Bomb    False                 True               False
# 2   Abe Sapien     True                 True               False
# 3     Abin Sur    False                False                True
# 4  Abomination    False                 True               False
#
#    Dimensional Awareness  Cold Resistance  Durability  Stealth  \
# 0                  False            False       False    False
# 1                  False            False        True    False
# 2                  False             True        True    False
# 3                  False            False       False    False
# 4                  False            False       False    False
#
#    Energy Absorption  Flight  ...  Web Creation  Reality Warping  Odin Force  \
# 0              False   False  ...         False            False       False
# ...

# %%
new_data = original_data.iloc[:, 0].to_frame()
new_data["ability_count"] = original_data.iloc[:, 1:].sum(axis=1)
new_data["hero_abilities"] = original_data.iloc[:, 1:].apply(
    lambda x: ", ".join(x.index[x]), axis=1
)
new_data.head()
# Out:
#     hero_names  ability_count  \
# 0      3-D Man              4
# 1       A-Bomb              7
# 2   Abe Sapien             16
# 3     Abin Sur              1
# 4  Abomination              8
#
#                                       hero_abilities
# 0      Agility, Super Strength, Stamina, Super Speed
# 1  Accelerated Healing, Durability, Longevity, Su...
# 2  Agility, Accelerated Healing, Cold Resistance,...
# 3                                 Lantern Power Ring
# 4  Accelerated Healing, Intelligence, Super Stren...

# %%
new_data
# Out:
#           hero_names  ability_count  \
# 0            3-D Man              4
# 1             A-Bomb              7
# 2         Abe Sapien             16
# 3           Abin Sur              1
# 4        Abomination              8
# ..               ...            ...
# 662  Yellowjacket II              3
# 663             Ymir              6
# 664             Yoda             19
# 665          Zatanna              8
# 666             Zoom              4
#
#                                         hero_abilities
# 0        Agility, Super Strength, Stamina, Super Speed
# 1    Accelerated Healing, Durability, Longevity, Su...
# 2    Agility, Accelerated Healing, Cold Resistance,...
# 3                                   Lantern Power Ring
# 4    Accelerated Healing, Intelligence, Super Stren...
# ..                                                 ...
# 662               Flight, Energy Blasts, Size Changing
# 663  Cold Resistance, Durability, Longevity, Super ...
# ...

# %%
# @title ability_count 1

from matplotlib import pyplot as plt
new_data['ability_count'].plot(kind='hist', bins=20, title='ability_count')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title ability_count 2

from matplotlib import pyplot as plt
new_data['ability_count'].plot(kind='line', figsize=(8, 4), title='ability_count')
plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# # Screenshots

# %% [markdown]
# ## filter + var
#
#
# ![**image**.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Errors

# %%
#l = [1, 2, 3]

#l[3]

# %%
#%debug
